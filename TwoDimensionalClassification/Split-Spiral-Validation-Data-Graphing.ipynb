# %%
import plygdata as pg
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from training import *
import numpy as np

# %%
validation_data_ratio=0.2

x_dim = ["1", "10", "20", "50", "100", "1000", "10000"]
y_dim = ["1", "10", "20", "50", "100", "1000", "10000"]
for x_val in x_dim:
    for y_val in y_dim:
        path = "../SampleData/SpiralStretch/ClassifySpiralDataNonSquare-{}-{}.txt".format(x_val, y_val)
        training_data_set = read_data_from_file(path)
        # This is the split data we will be using to generate all our graphs
        split_data = pg.split_data(training_data_set, validation_size=validation_data_ratio)
        print('X Val {}, Y Val {}'.format(str(x_val), str(y_val)))
        for std_factor in np.arange(0.1, 15, 0.5):
            print(str(std_factor) + '\t' + str(classify_data_by_point_set_validate(path, (-1, 1), split_data, normalization_standard_deviation_factor=std_factor)))
        print('------------------------------------')
# Out:
# X Val 1, Y Val 1
# 0.1	0.97
# 0.6	0.97
# 1.1	0.97
# 1.6	0.98
# 2.1	0.98
# 2.6	0.98
# 3.1	0.98
# 3.6	0.98
# 4.1	0.99
# 4.6	0.99
# 5.1	0.99
# 5.6	0.99
# /Personal/MADGE/madge_calculator.py:23: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# 6.1	0.99
# 6.6	0.99
# 7.1	0.99
# 7.6	0.99
# 8.1	0.99
# 8.6	1.0
# 9.1	1.0
# 9.6	1.0
# 10.1	1.0
# 10.6	1.0
# 11.1	1.0
# 11.6	1.0
# 12.1	1.0
# 12.6	1.0
# 13.1	1.0
# 13.6	1.0
# 14.1	1.0
# 14.6	1.0
# ------------------------------------
# X Val 1, Y Val 10
# /Personal/MADGE/classification_set_n.py:32: RuntimeWarning:
#
# invalid value encountered in true_divide
# 0.1	0.85
# 0.6	0.88
# 1.1	0.93
# 1.6	0.95
# 2.1	0.98
# 2.6	0.98
# 3.1	0.98
# 3.6	0.98
# 4.1	0.98
# 4.6	0.98
# /Personal/MADGE/classification_set_n.py:52: RuntimeWarning:
#
# invalid value encountered in true_divide
# 5.1	0.98
# 5.6	0.98
# 6.1	0.98
# 6.6	0.98
# 7.1	0.98
# 7.6	0.98
# 8.1	0.98
# 8.6	0.98
# 9.1	0.98
# 9.6	0.98
# 10.1	0.98
# 10.6	0.98
# 11.1	0.98
# 11.6	0.98
# 12.1	0.98
# 12.6	0.98
# 13.1	0.97
# 13.6	0.97
# 14.1	0.96
# 14.6	0.95
# ------------------------------------
# X Val 1, Y Val 20
# 0.1	0.68
# 0.6	0.73
# 1.1	0.75
# 1.6	0.79
# 2.1	0.85
# 2.6	0.85
# 3.1	0.89
# 3.6	0.91
# 4.1	0.91
# 4.6	0.92
# 5.1	0.92
# 5.6	0.92
# 6.1	0.94
# 6.6	0.93
# 7.1	0.93
# 7.6	0.93
# 8.1	0.89
# 8.6	0.89
# 9.1	0.88
# 9.6	0.87
# 10.1	0.87
# 10.6	0.87
# 11.1	0.87
# 11.6	0.85
# 12.1	0.85
# 12.6	0.85
# 13.1	0.83
# 13.6	0.83
# 14.1	0.83
# 14.6	0.82
# ------------------------------------
# X Val 1, Y Val 50
# 0.1	0.49
# 0.6	0.46
# 1.1	0.46
# 1.6	0.51
# 2.1	0.51
# 2.6	0.55
# 3.1	0.55
# 3.6	0.55
# 4.1	0.54
# 4.6	0.54
# 5.1	0.55
# 5.6	0.55
# 6.1	0.55
# 6.6	0.54
# 7.1	0.54
# 7.6	0.54
# 8.1	0.54
# 8.6	0.55
# 9.1	0.56
# 9.6	0.53
# 10.1	0.53
# 10.6	0.54
# 11.1	0.54
# 11.6	0.54
# 12.1	0.54
# 12.6	0.54
# 13.1	0.54
# 13.6	0.54
# 14.1	0.54
# 14.6	0.54
# ------------------------------------
# X Val 1, Y Val 100
# 0.1	0.53
# 0.6	0.49
# 1.1	0.47
# 1.6	0.44
# 2.1	0.44
# 2.6	0.42
# 3.1	0.42
# 3.6	0.42
# 4.1	0.42
# 4.6	0.43
# 5.1	0.43
# 5.6	0.43
# 6.1	0.43
# 6.6	0.43
# 7.1	0.43
# 7.6	0.43
# 8.1	0.43
# 8.6	0.43
# 9.1	0.43
# 9.6	0.43
# 10.1	0.43
# 10.6	0.43
# 11.1	0.43
# 11.6	0.43
# 12.1	0.43
# 12.6	0.43
# 13.1	0.42
# 13.6	0.42
# 14.1	0.41
# 14.6	0.41
# ------------------------------------
# X Val 1, Y Val 1000
# 0.1	0.21
# 0.6	0.21
# 1.1	0.2
# 1.6	0.18
# 2.1	0.18
# 2.6	0.17
# 3.1	0.17
# 3.6	0.17
# 4.1	0.17
# 4.6	0.17
# 5.1	0.17
# 5.6	0.17
# 6.1	0.17
# 6.6	0.17
# 7.1	0.17
# 7.6	0.17
# 8.1	0.17
# 8.6	0.17
# 9.1	0.17
# 9.6	0.17
# 10.1	0.17
# 10.6	0.17
# 11.1	0.17
# 11.6	0.17
# 12.1	0.17
# 12.6	0.17
# 13.1	0.17
# 13.6	0.17
# 14.1	0.17
# 14.6	0.17
# ------------------------------------
# X Val 1, Y Val 10000
# 0.1	0.05
# 0.6	0.05
# 1.1	0.05
# 1.6	0.05
# 2.1	0.05
# 2.6	0.05
# 3.1	0.05
# 3.6	0.05
# 4.1	0.05
# 4.6	0.05
# 5.1	0.05
# 5.6	0.05
# 6.1	0.05
# 6.6	0.05
# 7.1	0.05
# 7.6	0.05
# 8.1	0.05
# 8.6	0.05
# 9.1	0.05
# 9.6	0.05
# 10.1	0.05
# 10.6	0.05
# 11.1	0.05
# 11.6	0.05
# 12.1	0.05
# 12.6	0.05
# 13.1	0.05
# 13.6	0.05
# 14.1	0.05
# 14.6	0.05
# ------------------------------------
# X Val 10, Y Val 1
# 0.1	0.84
# 0.6	0.88
# 1.1	0.89
# 1.6	0.93
# 2.1	0.93
# 2.6	0.93
# 3.1	0.93
# 3.6	0.93
# 4.1	0.94
# 4.6	0.94
# 5.1	0.94
# 5.6	0.94
# 6.1	0.94
# 6.6	0.94
# 7.1	0.94
# 7.6	0.94
# 8.1	0.94
# 8.6	0.94
# 9.1	0.94
# 9.6	0.94
# 10.1	0.94
# 10.6	0.94
# 11.1	0.94
# 11.6	0.94
# 12.1	0.94
# 12.6	0.94
# 13.1	0.94
# 13.6	0.94
# 14.1	0.94
# 14.6	0.94
# ------------------------------------
# X Val 10, Y Val 10
# 0.1	1.0
# 0.6	0.99
# 1.1	0.99
# 1.6	0.99
# 2.1	0.99
# 2.6	0.99
# 3.1	0.99
# 3.6	0.99
# 4.1	0.99
# 4.6	0.99
# 5.1	0.99
# 5.6	0.99
# 6.1	0.99
